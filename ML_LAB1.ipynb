# %% [markdown]
# **LAB 1**

# %% [markdown]
# **TASK 1**

# %%
import pandas as pd
city_data=pd.read_csv('../dataset/city_day.csv')
city_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
city_data.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
city_data.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
city_data.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# ...

# %%
city_data.shape
# Out:
# (29531, 16)

# %%
print(city_data.duplicated().sum())
# Out:
# 0

# %%
print(city_data.isnull().sum())
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %% [markdown]
# city day dataset consists of daily environmental records for multiple Indian cities it has  29,531 rows and 16 columns
#
# it contains 13 specific pollutant measurements PM2.5, PM10, NO, NO2, NOx, NH3, CO, SO2, O3, Benzene, Toluene, and Xylene  and overall AQI and AQI_Bucket metrics
#
# the dataset has many missing values and zero duplicate values

# %%
crop_data=pd.read_csv('../dataset/crop_production.csv')
crop_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %%
crop_data.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %%
crop_data.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop', 'Area',
#        'Production'],
#       dtype='object')

# %%
crop_data.describe()
# Out:
#            Crop_Year          Area    Production
# count  246091.000000  2.460910e+05  2.423610e+05
# mean     2005.643018  1.200282e+04  5.825034e+05
# std         4.952164  5.052340e+04  1.706581e+07
# min      1997.000000  4.000000e-02  0.000000e+00
# 25%      2002.000000  8.000000e+01  8.800000e+01
# 50%      2006.000000  5.820000e+02  7.290000e+02
# 75%      2010.000000  4.392000e+03  7.023000e+03
# max      2015.000000  8.580100e+06  1.250800e+09

# %%
print(crop_data.duplicated().sum())
# Out:
# 0

# %%
print(crop_data.isnull().sum())
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %% [markdown]
# crop dataset consists of agricultural records across India it has  246,091 rows and 7 columnsState_Name,District_Name ,Season ,Crop_Year ,Crop , Area and Production
#
#  Production column  contains 3,730 missing values the dataset does not have any missing values

# %% [markdown]
# **TASK 2**

# %%
print("City Data Missing Values Before Cleaning")
print(city_data.isnull().sum())
if 'AQI_Bucket' in city_data.columns:
    city_data = city_data.drop(columns=['AQI_Bucket'])
numerical_cols_city = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI']
for col in numerical_cols_city:
    if city_data[col].isnull().any():
        median_val = city_data[col].median()
        city_data[col].fillna(median_val, inplace=True)

print("City Data  Missing Values After Cleaning ")
print(city_data.isnull().sum())
# Out:
# City Data Missing Values Before Cleaning
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64
# City Data  Missing Values After Cleaning
# City       0
# Date       0
# PM2.5      0
# PM10       0
# NO         0
# NO2        0
# NOx        0
# NH3        0
# CO         0
# SO2        0
# O3         0
# Benzene    0
# Toluene    0
# Xylene     0
# AQI        0
# dtype: int64
# C:\Users\Rehan\AppData\Local\Temp\ipykernel_13392\2017111127.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
print("Crop Data Missing Values Before Cleaning")
print(crop_data.isnull().sum())

if crop_data['Production'].isnull().any():
    median_production = crop_data['Production'].median()
    crop_data['Production'].fillna(median_production, inplace=True)

print("Crop Data  Missing Values After Cleaning")
print(crop_data.isnull().sum())
# Out:
# Crop Data Missing Values Before Cleaning
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64
# Crop Data  Missing Values After Cleaning
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64
# C:\Users\Rehan\AppData\Local\Temp\ipykernel_13392\2169984894.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# Missing values in the city air quality dataset were imputed using the column medians
#
# The median was  chosen over the mean because  high value outliers mean is affected by extreme values therefore median was taken for imputation

# %% [markdown]
# **TASK 3**

# %%
print(f"\nUnique cities in city_data before standardization: {city_data['City'].nunique()}")
city_data['City'] = city_data['City'].str.lower().str.strip()
print(f"Unique cities in city_data after standardization: {city_data['City'].nunique()}")


print(f"\nUnique state names in crop_data before standardization: {crop_data['State_Name'].nunique()}")
crop_data['State_Name'] = crop_data['State_Name'].str.lower().str.strip()
print(f"Unique state names in crop_data after standardization: {crop_data['State_Name'].nunique()}")

print("\n Removing Duplicates")

print(f"\nCity Data  Initial row count: {len(city_data)}")
duplicate_rows_city = city_data.duplicated(subset=['City', 'Date']).sum()
print(f"City Data  Number of duplicate rows found: {duplicate_rows_city}")
city_data.drop_duplicates(subset=['City', 'Date'], inplace=True)
print(f"City Data  Final row count after removing duplicates: {len(city_data)}")

print(f"\nCrop Data  Initial row count: {len(crop_data)}")
duplicate_rows_crop = crop_data.duplicated(subset=['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop', 'Area']).sum()
print(f"Crop Data  Number of duplicate rows found: {duplicate_rows_crop}")
crop_data.drop_duplicates(subset=['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop', 'Area'], inplace=True)
print(f"Crop Data  Final row count after removing duplicates: {len(crop_data)}")
# Out:
# Unique cities in city_data before standardization: 26
# Unique cities in city_data after standardization: 26
#
# Unique state names in crop_data before standardization: 33
# Unique state names in crop_data after standardization: 33
#
#  Removing Duplicates
#
# City Data  Initial row count: 29531
# City Data  Number of duplicate rows found: 0
# City Data  Final row count after removing duplicates: 29531
#
# Crop Data  Initial row count: 246091
# Crop Data  Number of duplicate rows found: 0
# Crop Data  Final row count after removing duplicates: 246091

# %% [markdown]
# **TASK 4**

# %% [markdown]
# ### Task 4

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(city_data['AQI'], bins=50, kde=True)
plt.title('Distribution of AQI in Indian Cities')
plt.xlabel('AQI Value')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# histogram was chosen to visualize the distribution of AQI values
#
# The distribution of AQI values is heavily right-skewed a large number of cities have relatively low to moderate AQI values

# %% [markdown]
# **TASK 5**

# %%
Q1 = city_data['AQI'].quantile(0.25)
Q3 = city_data['AQI'].quantile(0.75)
IQR = Q3 - Q1


upper_fence = Q3 + 1.5 * IQR

print(f"Q1 (25th percentile): {Q1:.2f}")
print(f"Q3 (75th percentile): {Q3:.2f}")
print(f"IQR: {IQR:.2f}")
print(f"Upper Fence (outlier boundary): {upper_fence:.2f}")


outliers_count = city_data[city_data['AQI'] > upper_fence].shape[0]
print(f"\nNumber of implausibly high AQI readings (outliers) detected: {outliers_count}")


city_data_treated = city_data.copy()
city_data_treated['AQI'] = city_data_treated['AQI'].apply(lambda x: upper_fence if x > upper_fence else x)

print(f"\nAQI values after capping will not exceed: {city_data_treated['AQI'].max():.2f}")
# Out:
# Q1 (25th percentile): 88.00
# Q3 (75th percentile): 179.00
# IQR: 91.00
# Upper Fence (outlier boundary): 315.50
#
# Number of implausibly high AQI readings (outliers) detected: 3192
#
# AQI values after capping will not exceed: 315.50

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
sns.histplot(city_data['AQI'], bins=50, kde=True, color='skyblue')
plt.title('Original AQI Distribution (Before Capping)')
plt.xlabel('AQI Value')
plt.ylabel('Frequency')
plt.axvline(x=upper_fence, color='red', linestyle='--', label=f'Upper Fence ({upper_fence:.2f})')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.subplot(1, 2, 2)
sns.histplot(city_data_treated['AQI'], bins=50, kde=True, color='lightcoral')
plt.title('AQI Distribution After Outlier Capping')
plt.xlabel('AQI Value (Capped)')
plt.ylabel('Frequency')
plt.axvline(x=upper_fence, color='red', linestyle='--', label=f'Capped at ({upper_fence:.2f})')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# The Original AQI Distribution plot clearly shows a long tail of high AQI values extending the upper fence indicating the presence of outliers
#
# After Outlier Capping plot this long tail is absent and all values above the calculated upper fence

# %% [markdown]
# **LAB 2**

# %% [markdown]
# **TASK 6**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

city_data['Date'] = pd.to_datetime(city_data['Date'])


city_data['Year'] = city_data['Date'].dt.year

annual_aqi = city_data.groupby('Year')['AQI'].mean().reset_index()


most_polluted_year = annual_aqi.loc[annual_aqi['AQI'].idxmax()]
least_polluted_year = annual_aqi.loc[annual_aqi['AQI'].idxmin()]

print("Annual Average AQI:")
print(annual_aqi)
print(f"\nMost Polluted Year: {most_polluted_year['Year']} with average AQI {most_polluted_year['AQI']:.2f}")
print(f"Least Polluted Year: {least_polluted_year['Year']} with average AQI {least_polluted_year['AQI']:.2f}")
# Out:
# Annual Average AQI:
#    Year         AQI
# 0  2015  179.615137
# 1  2016  176.554629
# 2  2017  161.777138
# 3  2018  175.217277
# 4  2019  154.578297
# 5  2020  113.737624
#
# Most Polluted Year: 2015.0 with average AQI 179.62
# Least Polluted Year: 2020.0 with average AQI 113.74

# %%
plt.figure(figsize=(12, 7))

sns.lineplot(x='Year', y='AQI', data=annual_aqi, marker='o', color='blue')





plt.scatter(most_polluted_year['Year'], most_polluted_year['AQI'], color='red', s=150, zorder=5, label=f"Most Polluted ({int(most_polluted_year['Year'])})')

plt.text(most_polluted_year['Year'], most_polluted_year['AQI'] + 5, f"{most_polluted_year['AQI']:.2f}", color='red', ha='center', va='bottom')





plt.scatter(least_polluted_year['Year'], least_polluted_year['AQI'], color='green', s=150, zorder=5, label=f"Least Polluted ({int(least_polluted_year['Year'])})')

plt.text(least_polluted_year['Year'], least_polluted_year['AQI'] - 10, f"{least_polluted_year['AQI']:.2f}", color='green', ha='center', va='top')



plt.title('Average Annual AQI Trend (2015-2023)')

plt.xlabel('Year')

plt.ylabel('Average AQI')

plt.xticks(annual_aqi['Year'].unique())

plt.grid(True, linestyle='--', alpha=0.7)

plt.legend()

plt.tight_layout()

plt.show()
# Out:
#   Cell In[43], line 5
#     plt.scatter(most_polluted_year['Year'], most_polluted_year['AQI'], color='red', s=150, zorder=5, label=f'Most Polluted ({int(most_polluted_year['Year'])})')
#                                                                                                                                                      ^
# SyntaxError: f-string: unmatched '['

# %% [markdown]
# The time-series plot of average annual AQI some years show a dip in pollution levels  followed by a rise in others the plot highlights specific years as significantly more or less polluted than the average indicating that air quality is influenced by a multiple  factors that vary year by year such as economic activity meteorological conditions and policy implementations

# %% [markdown]
# **TASK 7**

# %% [markdown]
# ### Task 7: Seasonality Check on AQI

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


city_data_treated['Date'] = pd.to_datetime(city_data_treated['Date'])
city_data_treated['Month'] = city_data_treated['Date'].dt.month

monthly_aqi_stats = city_data_treated.groupby('Month')['AQI'].agg(['mean', 'median', 'min', 'max', 'std']).reset_index()
print("Monthly AQI Statistics:")
print(monthly_aqi_stats)


month_names = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
city_data_treated['Month_Name'] = city_data_treated['Month'].map(month_names)

month_order = list(month_names.values())
# Out:
# Monthly AQI Statistics:
#     Month        mean  median   min    max        std
# 0       1  186.443915   148.0  36.0  315.5  89.400487
# 1       2  170.707163   129.0  42.0  315.5  84.869614
# 2       3  145.196435   118.0  26.0  315.5  73.781755
# 3       4  131.728164   118.0  18.0  315.5  71.744537
# 4       5  129.015243   118.0  14.0  315.5  70.107630
# 5       6  115.312522   107.0  16.0  315.5  66.316791
# 6       7  106.360883    96.0  20.0  315.5  59.799830
# 7       8  107.939770   100.0  22.0  315.5  60.298377
# 8       9  110.539577   100.0  14.0  315.5  60.631531
# 9      10  158.246575   118.0  13.0  315.5  85.501388
# 10     11  190.909814   156.0  14.0  315.5  95.954819
# 11     12  188.517146   153.0  26.0  315.5  90.041164

# %%
plt.figure(figsize=(14, 7))
sns.boxplot(x='Month_Name', y='AQI', data=city_data_treated, order=month_order, palette='viridis')
plt.title('AQI Distribution Across Months')
plt.xlabel('Month')
plt.ylabel('AQI')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1011/2290748636.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Month_Name', y='AQI', data=city_data_treated, order=month_order, palette='viridis')

# %% [markdown]
# The box plot visualizing AQI distribution across months the Oct–Dec harvest season AQI values generally begin to rise around October, peak in November and December, and remain relatively high into January and February before decreasing in the spring and summer months

# %% [markdown]
# **TASK 8**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

city_to_state_mapping = {
    'ahmedabad': 'gujarat',
    'bengaluru': 'karnataka',
    'chennai': 'tamil nadu',
    'delhi': 'delhi',
    'hyderabad': 'telangana',
    'kolkata': 'west bengal',
    'mumbai': 'maharashtra',
    'jaipur': 'rajasthan',
    'kanpur': 'uttar pradesh',
    'lucknow': 'uttar pradesh',
    'patna': 'bihar',
    'bhopal': 'madhya pradesh',
    'chandigarh': 'chandigarh',
    'amritsar': 'punjab',
    'coimbatore': 'tamil nadu',
    'gurugram': 'haryana',
    'indore': 'madhya pradesh',
    'kochi': 'kerala',
    'shillong': 'meghalaya',
    'visakhapatnam': 'andhra pradesh',
    'guwahati': 'assam',
    'eranakulam': 'kerala',
    'amaravati': 'andhra pradesh',
    'brahmapur': 'odisha',
    'aisbagh': 'uttar pradesh'
}

city_data_treated['State_Name'] = city_data_treated['City'].map(city_to_state_mapping)
city_data_agg = city_data_treated.dropna(subset=['State_Name']).copy()
city_data_agg['State_Name'] = city_data_agg['State_Name'].str.lower().str.strip()
city_data_agg['Year'] = city_data_agg['Date'].dt.year

pollutant_cols = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI']
city_yearly_avg = city_data_agg.groupby(['State_Name', 'Year'])[pollutant_cols].mean().reset_index()

display(city_yearly_avg.head())
print(f"Shape of transformed city data: {city_yearly_avg.shape}")

crop_data_renamed = crop_data.rename(columns={'Crop_Year': 'Year'}).copy()
crop_data_renamed['State_Name'] = crop_data_renamed['State_Name'].str.lower().str.strip()
crop_yearly_sum = crop_data_renamed.groupby(['State_Name', 'Year'])[['Production', 'Area']].sum().reset_index()

display(crop_yearly_sum.head())
print(f"Shape of transformed crop data: {crop_yearly_sum.shape}")

merged_data = pd.merge(city_yearly_avg, crop_yearly_sum, on=['State_Name', 'Year'], how='outer')

display(merged_data.head())
print(f"Shape of merged data: {merged_data.shape}")

plt.figure(figsize=(16, 12))
sns.heatmap(merged_data.drop(columns=['Year']).corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Air Quality and Crop Production Features')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
#        State_Name  Year      PM2.5        PM10         NO        NO2  \
# 0  andhra pradesh  2016  45.000326   88.183424  16.441685  41.732935
# 1  andhra pradesh  2017  55.534665  105.359181  10.851141  27.669380
# 2  andhra pradesh  2018  44.188247   98.876329   9.045822  32.125795
# 3  andhra pradesh  2019  43.761781   97.057301   9.452096  30.059767
# 4  andhra pradesh  2020  29.325000   66.782951   4.341557  20.133852
#
#          NOx        NH3        CO        SO2         O3   Benzene    Toluene  \
# 0  32.540435  13.457337  1.082935  21.189837  43.114620  6.072011  10.410543
# 1  13.386427  12.452655  0.474988  10.266055  43.871290  1.740000   3.704938
# 2  24.504507  13.286082  0.731315  11.553205  37.329671  2.757219   6.255247
# 3  23.923178  10.268370  0.767425  13.747822  34.055699  2.252973   5.678014
# 4  14.124727  10.959372  0.603525  12.122951  31.289426  1.816776   4.787732
#
#      Xylene         AQI
# 0  6.642663  105.271739
# 1  1.082829  134.741935
# ...

# %% [markdown]
# To merge city data treate air quality and crop data crop production both datasets are transformed to a State Name and Year
#
# Cities are mapped to states   Year  is extracted from Date and then aggregated by State Name and Year using the mean for AQI and pollutant columns
# crop data Crop Year is renamed to Year then aggregated by State Name and Year using the sum for Production and Area
#
# An outer merge is performed on the aggregated DataFrames using State Name and Year
#
# Higher AQI  correlate with lower crop Production and Area
#
# Many pollutants  show strong positive correlations

# %% [markdown]
# **TASK 9**

# %% [markdown]
# **Key Findings**
#
# Air pollution consistently worsens during the October to December harvest season
#
# when air quality is poor crop production tends to decrease This indicates a direct impact of dirty air on our agricultural output
#
#  We have not seen a steady improvement or decline in overall air quality over the years  it changes a lot from one year to the next
#
# **Actionable Recommendation**
#
# To safeguard public health and agriculture we strongly recommend implementing targeted policies to reduce seasonal pollution especially during the harvest months
#
# Collaborating with the Ministry of Agriculture to promote cleaner farming practices, such as discouraging crop residue burning, could yield significant benefits for both air quality and food security.
#
# **Data Limitation**
#
# Our analysis is based on available data  but the information for cities and states was not always  uniform across all years a more  consistent data collection  would allow for more precise conclusions

# %% [markdown]
# **TASK A**

# %%
state_aqi = city_yearly_avg.groupby('State_Name')['AQI'].mean()
state_prod = crop_yearly_sum.groupby('State_Name')['Production'].sum()

most_polluted_state = state_aqi.idxmax()
least_polluted_state = state_aqi.idxmin()

print(f"Most polluted state: {most_polluted_state} (AQI: {state_aqi.max():.1f})")
print(f"Least polluted state: {least_polluted_state} (AQI: {state_aqi.min():.1f})")

prod_most = state_prod.get(most_polluted_state, 0)
prod_least = state_prod.get(least_polluted_state, 0)

fig, ax = plt.subplots(1, 2, figsize=(12, 5))

states = [most_polluted_state, least_polluted_state]
aqi_vals = [state_aqi[most_polluted_state], state_aqi[least_polluted_state]]
prod_vals = [prod_most, prod_least]
colors = ['red', 'green']

ax[0].bar(states, aqi_vals, color=colors, alpha=0.7)
ax[0].set_ylabel('Mean AQI')
ax[0].set_title('AQI: Most vs Least Polluted States')
ax[0].tick_params(axis='x', rotation=15)

ax[1].bar(states, prod_vals, color=colors, alpha=0.7)
ax[1].set_ylabel('Total Production')
ax[1].set_title('Crop Production: Most vs Least Polluted States')
ax[1].tick_params(axis='x', rotation=15)

plt.tight_layout()
plt.show()
# Out:
# Most polluted state: delhi (AQI: 227.9)
# Least polluted state: meghalaya (AQI: 76.5)

# %% [markdown]
# The most polluted state Delhi produces less than the least polluted Meghalaya higher pollution correlates with specific seasons not uniform state-level industrialization

# %% [markdown]
# **TASK B**

# %%
from scipy.stats import pearsonr

state_aqi_dict = city_yearly_avg.groupby('State_Name')['AQI'].mean().to_dict()
state_prod_dict = crop_yearly_sum.groupby('State_Name')['Production'].sum().to_dict()

aqi_states = set(state_aqi_dict.keys())
crop_states = set(state_prod_dict.keys())
common_states = sorted(list(aqi_states.intersection(crop_states)))

print(f"AQI states: {len(aqi_states)}")
print(f"Crop states: {len(crop_states)}")
print(f"Common states: {len(common_states)}")

state_aqi_vals = [state_aqi_dict[s] for s in common_states]
state_prod_vals = [state_prod_dict[s] for s in common_states]

correlation, p_value = pearsonr(state_aqi_vals, state_prod_vals)
print(f"\nPearson correlation (Common states AQI vs Production): {correlation:.3f}")
print(f"P-value: {p_value:.4f}")
print(f"R-squared (variance explained): {correlation**2:.3f}")

strength = "very weak" if abs(correlation) < 0.2 else ("weak" if abs(correlation) < 0.4 else ("moderate" if abs(correlation) < 0.7 else "strong"))
direction = "negative" if correlation < 0 else "positive"
print(f"\nInterpretation: {strength.capitalize()} {direction} correlation")

plt.figure(figsize=(10, 6))
plt.scatter(state_aqi_vals, state_prod_vals, alpha=0.6, s=100)

for i, state in enumerate(common_states):
    if i % 2 == 0:
        plt.annotate(state, (state_aqi_vals[i], state_prod_vals[i]), fontsize=8, alpha=0.5)

plt.xlabel('Mean AQI by State')
plt.ylabel('Total Production by State')
plt.title(f'State-level: AQI vs Crop Production (r={correlation:.3f}, p={p_value:.3f})')

z = np.polyfit(state_aqi_vals, state_prod_vals, 1)
p_func = np.poly1d(z)
sorted_aqi = np.sort(state_aqi_vals)
plt.plot(sorted_aqi, p_func(sorted_aqi), "r--", alpha=0.8, linewidth=2, label=f'Trend line')

plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# AQI states: 18
# Crop states: 33
# Common states: 17
#
# Pearson correlation (Common states AQI vs Production): -0.214
# P-value: 0.4085
# R-squared (variance explained): 0.046
#
# Interpretation: Weak negative correlation
# === Research Note ===
# This weak negative correlation (r=-0.214, p=0.409) suggests:
# 1. AQI and production are NOT strongly linked at state level
# 2. The relationship explains only 4.6% of variation
# 3. Other factors (rainfall, soil, irrigation, farmer income, technology) likely have MUCH larger effects
# 4. CRITICAL: Correlation ≠ causation. A true causal study would need to control for these confounders

# %% [markdown]
# AQI and production are NOT strongly linked at state level
#
# The relationship explains only 4.6% of variation
#
# Other factors rainfall, soil, irrigation farmer income technology likely have much larger effects
